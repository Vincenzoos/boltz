# %% [markdown]
# # Boltz UI

# %%
# %pip install -q 'ipywidgets>=8' jupyterlab_widgets widgetsnbextension pyyaml
import ipywidgets
print(f'ipywidgets {ipywidgets.__version__} OK')
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ipywidgets 8.1.8 OK

# %%
import sys
from pathlib import Path

# Requires Boltz_Remodel_UI.ipynb to be stored in repo_root/notebooks/
ROOT = Path.cwd().resolve()
if ROOT.name == "notebooks":
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT))

from add_ons.predict_ui import launch_ui

launch_ui()
# Out:
# Tab(children=(VBox(children=(HTML(value='<div style="background:#dbeafe;padding:12px 16px;border-radius:6px;ma…
